# %%
import re
with open('s&p600_raw_list.txt', 'r') as f:
    sp600 = f.read()
regex = '>[A-Z]{2,5}</a>'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 import re
# ----> 2 with open('s&p600_raw_list.txt', 'r') as f:
#       3     sp600 = f.read()
#       4 regex = '>[A-Z]{2,5}</a>'
#
# FileNotFoundError: [Errno 2] No such file or directory: 's&p600_raw_list.txt'

# %%
tickers = re.findall(r'>[A-Z]{2,5}</a>', sp600)
tickers
# Out:
# ['>GICS</a>',
#  '>CIK</a>',
#  '>AAMI</a>',
#  '>AAP</a>',
#  '>AAT</a>',
#  '>ABCB</a>',
#  '>ABG</a>',
#  '>ABM</a>',
#  '>ABR</a>',
#  '>ACA</a>',
#  '>ACAD</a>',
#  '>ACHC</a>',
#  '>ACIW</a>',
#  '>ACLS</a>',
#  '>ACMR</a>',
#  '>ACT</a>',
#  '>ADAM</a>',
#  '>ADEA</a>',
#  '>ADMA</a>',
#  '>ADNT</a>',
#  '>ADT</a>',
#  '>ADUS</a>',
#  '>AEO</a>',
#  '>AESI</a>',
#  '>AGNT</a>',
#  '>AGO</a>',
#  '>AGX</a>',
#  '>AGYS</a>',
#  '>AHCO</a>',
#  '>AIN</a>',
#  '>AIR</a>',
#  '>AKR</a>',
#  '>ALG</a>',
#  '>ALGT</a>',
#  '>ALHC</a>',
#  '>ALKS</a>',
#  '>ALRM</a>',
#  '>AMN</a>',
#  '>AMPH</a>',
#  '>AMR</a>',
#  '>AMRX</a>',
#  '>AMSF</a>',
#  '>AMTM</a>',
#  '>ANDE</a>',
#  '>ANIP</a>',
#  '>AORT</a>',
#  '>AOSL</a>',
#  '>APAM</a>',
#  '>APLE</a>',
#  '>APOG</a>',
#  '>ARCB</a>',
#  '>ARI</a>',
#  '>ARLO</a>',
#  '>AROC</a>',
#  '>ARR</a>',
#  '>ASO</a>',
#  '>ASTE</a>',
#  '>ASTH</a>',
#  '>ATEN</a>',
#  '>ATMU</a>',
#  '>AUB</a>',
#  '>AVA</a>',
#  '>AVNS</a>',
#  '>AWI</a>',
# ...

# %%
for i in range(len(tickers)):
    tickers[i] = (re.sub('[></a]', "", tickers[i]))
tickers
# Out:
# ['GICS',
#  'CIK',
#  'AAMI',
#  'AAP',
#  'AAT',
#  'ABCB',
#  'ABG',
#  'ABM',
#  'ABR',
#  'ACA',
#  'ACAD',
#  'ACHC',
#  'ACIW',
#  'ACLS',
#  'ACMR',
#  'ACT',
#  'ADAM',
#  'ADEA',
#  'ADMA',
#  'ADNT',
#  'ADT',
#  'ADUS',
#  'AEO',
#  'AESI',
#  'AGNT',
#  'AGO',
#  'AGX',
#  'AGYS',
#  'AHCO',
#  'AIN',
#  'AIR',
#  'AKR',
#  'ALG',
#  'ALGT',
#  'ALHC',
#  'ALKS',
#  'ALRM',
#  'AMN',
#  'AMPH',
#  'AMR',
#  'AMRX',
#  'AMSF',
#  'AMTM',
#  'ANDE',
#  'ANIP',
#  'AORT',
#  'AOSL',
#  'APAM',
#  'APLE',
#  'APOG',
#  'ARCB',
#  'ARI',
#  'ARLO',
#  'AROC',
#  'ARR',
#  'ASO',
#  'ASTE',
#  'ASTH',
#  'ATEN',
#  'ATMU',
#  'AUB',
#  'AVA',
#  'AVNS',
#  'AWI',
#  'AWR',
#  'AX',
#  'AZTA',
#  'AZZ',
#  'BANC',
#  'BANF',
#  'BANR',
#  'BBT',
#  'BCC',
#  'BCPC',
#  'BFAM',
#  'BFH',
#  'BFS',
#  'BGC',
#  'BHE',
#  'BJRI',
#  'BKE',
#  'BKU',
#  'BL',
#  'BLFS',
#  'BMI',
#  'BNL',
#  'BOH',
#  'BOOT',
#  'BOX',
#  'BRC',
#  'BTSG',
#  'BTU',
#  'BXMT',
#  'CABO',
# ...

# %%
len(tickers)
# Out:
# 604
